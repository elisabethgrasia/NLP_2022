# %% [markdown]
# ## Assignment Natural Language Understanding
#
# Elisabeth Putri - 20306250

# %% [markdown]
# ##### Sentiment analysis using logistic regression
#
# Train a binary classifier for classifying movie reviews from IMDB database. The task is to classify them as positive or
# negative.

# %%
# importing the libraries
import os, re
import numpy as np
import pandas as pd
import time
import random
from pathlib import Path
from collections import Counter

# %% [markdown]
# After importing the libraries, we are going to access the files directory.

# %%
imdb = list(os.walk('imdb_dataset', topdown = False))

for address, dirs, files in imdb:
    data_dirs = []
    for name in files:
        data_dirs = data_dirs + [os.path.join(address, name)]
        print()
# Out:
# imdb_dataset\neg2\0_2.txt
# imdb_dataset\neg2\0_3.txt
# imdb_dataset\neg2\10000_4.txt
# imdb_dataset\neg2\10001_1.txt
# imdb_dataset\neg2\10001_4.txt
# imdb_dataset\neg2\10002_1.txt
# imdb_dataset\neg2\10002_3.txt
# imdb_dataset\neg2\10003_1.txt
# imdb_dataset\neg2\10003_3.txt
# imdb_dataset\neg2\10004_2.txt
# imdb_dataset\neg2\10004_3.txt
# imdb_dataset\neg2\10005_2.txt
# imdb_dataset\neg2\10005_3.txt
# imdb_dataset\neg2\10006_2.txt
# imdb_dataset\neg2\10006_4.txt
# imdb_dataset\neg2\10007_1.txt
# imdb_dataset\neg2\10007_4.txt
# imdb_dataset\neg2\10008_2.txt
# imdb_dataset\neg2\10008_4.txt
# imdb_dataset\neg2\10009_1.txt
# imdb_dataset\neg2\10009_3.txt
# imdb_dataset\neg2\1000_3.txt
# imdb_dataset\neg2\1000_4.txt
# imdb_dataset\neg2\10010_2.txt
# imdb_dataset\neg2\10010_3.txt
# imdb_dataset\neg2\10011_1.txt
# imdb_dataset\neg2\10011_3.txt
# imdb_dataset\neg2\10012_1.txt
# imdb_dataset\neg2\10013_1.txt
# imdb_dataset\neg2\10013_4.txt
# imdb_dataset\neg2\10014_2.txt
# ...

# %%
neg = []
pos = []
reneg = re.compile('imdb\\neg2\\*.txt')
for a in data_dirs:
    if reneg.match(a):
        neg.append(a)
    else:
        pos.append(a)
print(neg, pos)
# Out:
# [] ['imdb_dataset\\pos2\\1186_8.txt']

# %%
print(data_dirs)
# Out:
# ['imdb_dataset\\pos2\\1186_8.txt']

# %%
for root, subfolders, filenames in os.walk("imdb_datasets"):
    data_dirs = []
    neg = []
    pos = []
    if subfolders=="neg2":
        for filename in filenames:
            neg = Path('neg2/ filename')
    if subfolders=="pos2":
        for filename in filenames:
            pos = Path('pos2/ filename')
    data_dirs.append(neg, pos)
return data_dirs


r_dir = os.walk("imdb_dataset").__next__()[0]
d_dir = os.walk("imdb_dataset").__next__()[1]  
data_dirs = [os.path.join(r_dir, d1)  for d1 in d_dir]
# Out:
# <generator object _walk at 0x0000020900206040>
# ('imdb_dataset', ['neg2', 'pos2'], [])
# ...

# %% [markdown]
# Accessing each files from data_dirs variable.

# %%
import os
def train_test_split(): 
#the following lists contain the file names in the 'neg' and 'pos' directories respectively
    neg_dir = os.walk(data_dirs[0]).__next__()[2]
    pos_dir = os.walk(data_dirs[1]).__next__()[2]
    return tr, ts

# %% [markdown]
# Creating vocabulary from each class.

# %%
for a in data_dirs:
    while True:
        with open('austen/emma.txt', 'r', encoding="utf-8") as f:
        emma = f.read()
        f.close()
        print(emma[0:10])

# %%
# Get rid of punctuation but keep the spaces, be careful with the stopwords
from nltk.corpus import stopwords

# %%
# map each document into a vector

# %%
# creating tf/idf

# %%
# logistic regression to the training set to fix the weights. Use sklearn logistic regression from linear models.
from sklearn.linear_model import LogisticRegression

# %%
# test the model, report accuracy, recall and precision
